# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
groq_api_key = os.getenv("GROQ_API_KEY")
print("GROQ API Key:", )
# Out:
# GROQ API Key:

# %%
# from langchain_groq import GroqEmbeddings
# GroqEmbeddings(model="llama-3.1-8b-instant", api_key  = groq_api_key)

# from langchain_groq import GroqEmbeddings

# embeddings = GroqEmbeddings(
#     model="llama-3.1-8b-instant",
#     api_key=groq_api_key
# )



from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(
    model="text-embedding-3-large",  
    openai_api_key=groq_api_key,     # Groq uses OpenAI-compatible API
    api_base="https://api.groq.com/openai/v1"
)
# Out:
# C:\Users\fakee\AppData\Roaming\Python\Python312\site-packages\langchain_openai\embeddings\base.py:270: UserWarning: WARNING! api_base is not default parameter.
#                     api_base was transferred to model_kwargs.
#                     Please confirm that api_base is what you intended.
#   warnings.warn(
